# %% [raw]
# print("Naz")  #Testing

# %%
#Libraries
import numpy as np
import pandas as pd

# %%
#Import Data
data = pd.read_csv('../input/titanic/train.csv', encoding='latin-1')
data.head(5)
data_test=pd.read_csv('../input/titanic/test.csv', encoding='latin-1')
#data_test.head(5)

# %%
#Exploration
data.shape #891 rows and 12 columns

# %%
data.Cabin.value_counts() #Distinct cabins with many ppl

# %%
data.Embarked.value_counts()

# %%
import seaborn as sns
sex_count=data.Sex.value_counts()
sns.barplot(sex_count.index, sex_count.values)

# %%
sex_count

# %% [markdown]
# **Data preprocessing**

# %%
data.isnull().sum() #missing values

# %%
for i in data.columns:  
    data[i]=data[i].fillna(data[i].mode()[0]) #filling missing values with mode values

# %%
data

# %%
data['Age*Class']=data['Age']*data['Pclass'] #Feature_engineering
data['Family_Size']=data['SibSp']+data['Parch']
data['Fare_Per_Person']=data['Fare']/(data['Family_Size']+1)
data

# %%
import string
def substrings_in_string(big_string, substrings):
    for substring in substrings:
        if str.find(big_string, substring) != -1:
            return substring
    print (big_string)
    return np.nan

# %%
title_list=['Mrs', 'Mr', 'Master', 'Miss', 'Major', 'Rev',
                    'Dr', 'Ms', 'Mlle','Col', 'Capt', 'Mme', 'Countess',
                    'Don', 'Jonkheer']

data['Title']=data['Name'].map(lambda x: substrings_in_string(x, title_list))
 
#replacing all titles with mr, mrs, miss, master
def replace_titles(x):
    title=x['Title']
    if title in ['Don', 'Major', 'Capt', 'Jonkheer', 'Rev', 'Col']:
        return 'Mr'
    elif title in ['Countess', 'Mme']:
        return 'Mrs'
    elif title in ['Mlle', 'Ms']:
        return 'Miss'
    elif title =='Dr':
        if x['Sex']=='Male':
            return 'Mr'
        else:
            return 'Mrs'
    else:
        return title
data['Title']=data.apply(replace_titles, axis=1)

# %%
data=data.drop(columns=['Name','Ticket'])

# %% [markdown]
# #Converting categorical to numerical

# %%
data.Sex = data.Sex.astype('category') #Converting to categorical
data.Cabin=data.Cabin.astype('category')
data.Embarked=data.Embarked.astype('category')
data.Title=data.Title.astype('category')

# %%
data.Sex

# %%
data.Sex=data.Sex.cat.codes
data.Cabin=data.Cabin.cat.codes
data.Embarked=data.Embarked.cat.codes
data.Title=data.Title.cat.codes

# %%
data.Age.dtype

# %%
from scipy import stats #Removing Outliers
z_scores=stats.zscore(data)
z_scores= np.abs(z_scores)
z_scores
data=data[(z_scores<3).all(axis=1)]
data.shape

# %%
data

# %%
for i in data.columns:
    print(i)

# %%
data.Cabin.head(10)

# %%
data.Fare.value_counts()

# %%
Fare_count=data.Fare.value_counts()
Fare_count.values.shape

# %%
sns.barplot(Fare_count.index, Fare_count.values)

# %%
data.dtypes

# %%
data

# %%
data.Fare.mean()

# %%
import matplotlib.pyplot as plt
plt.scatter(data.Fare.index, data.Fare.values)

# %%
plt.plot(data.Fare.index, data.Fare.values)

# %%
data.Fare.describe()

# %% [raw]
# for i in data.Fare:
#     if i<=10:
#      data.Fare=data.Fare.replace(i, 'Low')
#     elif (i<= 26 and i>= 11):
#      data.Fare=data.Fare.replace(i, 'Medium')
#     else:
#      data.Fare=data.Fare.replace(i, 'High')

# %% [raw]
# data.Fare=data.Fare.astype('category')
# data.Fare=data.Fare.cat.codes

# %%
data.Age.median

# %%
sns.barplot(data.Age.index, data.Age.values)

# %%
sns.barplot(data.Age.values, data.Age.index)

# %% [raw]
# data.Age=data.Age.astype('category')
# data.Age=data.Age.cat.codes
# data.Age

# %%
data

# %%
column_names = ['PassengerId','Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
       'Fare', 'Cabin', 'Embarked', 'Survived']

# %%
data.reindex(columns=column_names)

# %% [raw]
# y=data.Cabin
# X=data.drop('Cabin', axis=1)
# X

# %%
y=data.Survived
X=data.drop('Survived', axis=1)
X

# %%
data.columns

# %%
data.dtypes

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.3, random_state=42)

# %%
import sklearn
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LogisticRegression
LR = sklearn.linear_model.LogisticRegression(random_state=0, solver='lbfgs', multi_class='ovr').fit(X, y)
LR.fit(X_train,y_train)
y_pred=LR.predict(X_test)
print(accuracy_score(y_pred, y_test))

# %%
X

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors=19)
KNN.fit(X_train, y_train)
y_pred=KNN.predict(X_test)
print(accuracy_score(y_pred, y_test))

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print(accuracy_score(y_pred, y_test))

# %%
from sklearn.tree import DecisionTreeClassifier
DTC = DecisionTreeClassifier()
DTC.fit(X_train,y_train)
y_pred=DTC.predict(X_test)
print(accuracy_score(y_pred, y_test))

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier()
RFC.fit(X_train,y_train)
y_pred=RFC.predict(X_test)
print(accuracy_score(y_pred, y_test))

# %%
from sklearn.naive_bayes import GaussianNB
GNB = GaussianNB()
GNB.fit(X_train,y_train)
y_pred=GNB.predict(X_test)
print(accuracy_score(y_pred, y_test))

# %%
from sklearn.cluster import KMeans
KM= KMeans()
KM.fit(X_train,y_train)
y_pred=KM.predict(X_test)
print(accuracy_score(y_pred, y_test))

# %%
dir(sklearn.cluster)

# %%
data

# %% [markdown]
# Final Model

# %%
for i in data_test.columns:  
    data_test[i]=data_test[i].fillna(data_test[i].mode()[0]) #filling missing values with mode values

# %%
data_test['Title']=data_test['Name'].map(lambda x: substrings_in_string(x, title_list))
data_test['Title']=data_test.apply(replace_titles, axis=1)

# %%
data_test['Age*Class']=data_test['Age']*data_test['Pclass'] #Feature_engineering
data_test['Family_Size']=data_test['SibSp']+data_test['Parch']
data_test['Fare_Per_Person']=data_test['Fare']/(data_test['Family_Size']+1)

# %%
data_test.Sex = data_test.Sex.astype('category') #Converting to categorical
data_test.Cabin=data_test.Cabin.astype('category')
data_test.Embarked=data_test.Embarked.astype('category')
data_test.Title=data_test.Title.astype('category')

# %%
data_test.Sex=data_test.Sex.cat.codes
data_test.Cabin=data_test.Cabin.cat.codes
data_test.Embarked=data_test.Embarked.cat.codes
data_test.Title=data_test.Title.cat.codes

# %%
data_test=data_test.drop(columns=['Name','Ticket'])

# %%
data_test

# %%
y_pred=LR.predict(data_test)
y_pred

# %%
data_test['Survived']=y_pred

# %%
gender_submission=data_test[['PassengerId','Survived']].copy()

# %%
gender_submission

# %%
gender_submission.to_csv('gender_submission.csv', index=False)
